# %%
import random

# %%
UserWins = 0
UserLoss = 0
CompWins = 0
CompLoss = 0
Tie = 0

# %%
def Userwin(UserWins, CompLoss):
    print('\n Computer lost 1 point')
    CompLoss = CompLoss + 1
    print('User earned 1 point')
    UserWins = UserWins + 1
    print("Total earned points by User : ", UserWins)
    return UserWins, CompLoss

# %%
def Compwin(UserLoss, CompWins):
    print('\n User lost 1 point')
    UserLoss = UserLoss + 1
    print('Computer earned 1 point')
    CompWins = CompWins + 1
    print("Total earned points by Computer : ", CompWins)
    return UserLoss, CompWins

# %%
print('************************Welcome to ROCK-PAPER-SCISSOR Game**********************')
print("                                Let's get started....")
print("----------------------------------------------------------------------------------")


while(1):
    print('\n\n 1.R for Rock \n 2.P for Paper \n 3.S for Scissor \n 4.E for Exit')
    UserInput = input('\n Enter your choice:')
    
    if(UserInput == 'R' or UserInput == 'P' or UserInput == 'S' or UserInput == 'E'):
        pass
    
    else:
        print('Wrong choice')
        continue

    CompChoice = ['R','P','S']
    CompInput = str(random.choice(CompChoice))     
        
        
    if(UserInput == CompInput):
        print("It is Tie")
        Tie = Tie + 1
        print('Total no of ties: ', Tie)
        
                
    elif(UserInput == 'E'):
        
        if(UserWins == CompWins):
            print('\n\nIt is a Tie!!!!  Well played')
            
        elif(UserWins > CompWins):
            print('\n\n */*/*/*/*/*/*/*Congratulations!!*\*\*\*\*\*\*\*')
            print("You win!!")
            
        else:
            print("\n\n You lose!!")
            print('Better try next time!!')
            
        print("\n\n\n\n ************************************************SCOREBOARD**************************************************")
        print('\n --------------------------------------------------------------------------------------------------------------')
        print('\t\t User \t\t\t\t\t\t\t Computer')
        print('--------------------------------------------------------------------------------------------------------------')
        print('\t\t Losses: ', UserLoss, ' \t\t\t\t\t\t Losses: ', CompLoss)
        print('\t\t Wins: ', UserWins, ' \t\t\t\t\t\t Wins: ', CompWins)
        print('\t\t\t\t\t\t Total Ties: ', Tie)
        print('--------------------------------------------------------------------------------------------------------------')
        break;
        
                
    elif(UserInput != CompInput):
        if(UserInput == 'R' and CompInput == 'S'):
            UserWins, CompLoss = Userwin(UserWins, CompLoss)

        elif(UserInput == 'R' and CompInput == 'P'):
            UserLoss, CompWins = Compwin(UserLoss, CompWins)

        elif(UserInput == 'S' and CompInput == 'R'):
            UserLoss, CompWins = Compwin(UserLoss, CompWins)

        elif(UserInput == 'P' and CompInput == 'R'):
            UserWins, CompLoss = Userwin(UserWins, CompLoss)

        elif(UserInput == 'P' and CompInput == 'S'):
            UserLoss, CompWins = Compwin(UserLoss, CompWins)

        elif(UserInput == 'S' and CompInput == 'P'):
            UserWins, CompLoss = Userwin(UserWins, CompLoss)
# Out:
# ************************Welcome to ROCK-PAPER-SCISSOR Game**********************
#                                 Let's get started....
# ----------------------------------------------------------------------------------
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  1
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  1
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
# It is Tie
# Total no of ties:  1
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  2
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
# It is Tie
# Total no of ties:  2
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  3
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  4
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:R
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  2
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  3
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  4
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
# It is Tie
# Total no of ties:  3
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
# It is Tie
# Total no of ties:  4
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  5
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
# It is Tie
# Total no of ties:  5
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
# It is Tie
# Total no of ties:  6
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  6
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:P
# It is Tie
# Total no of ties:  7
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
# It is Tie
# Total no of ties:  8
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  5
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  7
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
#
#  Computer lost 1 point
# User earned 1 point
# Total earned points by User :  8
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
# It is Tie
# Total no of ties:  9
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
#
#  User lost 1 point
# Computer earned 1 point
# Total earned points by Computer :  6
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
# It is Tie
# Total no of ties:  10
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:S
# It is Tie
# Total no of ties:  11
#
#
#  1.R for Rock
#  2.P for Paper
#  3.S for Scissor
#  4.E for Exit
#
#  Enter your choice:E
#
#
#  */*/*/*/*/*/*/*Congratulations!!*\*\*\*\*\*\*\*
# You win!!
#
#
#
#
#  ************************************************SCOREBOARD**************************************************
#
#  --------------------------------------------------------------------------------------------------------------
# 		 User 							 Computer
# --------------------------------------------------------------------------------------------------------------
# 		 Losses:  6  						 Losses:  8
# 		 Wins:  8  						 Wins:  6
# 						 Total Ties:  11
# --------------------------------------------------------------------------------------------------------------
